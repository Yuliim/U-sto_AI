# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuliim/U-sto_AI/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
#   File "/tmp/ipython-input-1009182614.py", line 3
#     git clone https://github.com/username/repo.git  # 레포 복제
#         ^
# SyntaxError: invalid syntax
